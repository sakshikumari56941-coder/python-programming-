# %%
print('ayushisharma')
# Out:
# ayushisharma

# %%
x=7866
y=8876
e=2340
i=(x+y+e)
print(i)
# Out:
# 19082

# %%
x="water"
u="ice"
p="snow"
k="rain"
r=(x,u,p,k)
print(r)
# Out:
# ('water', 'ice', 'snow', 'rain')

# %%
x=[1,2,3,4] #list
y=['a','b','c','d']

# %%
x=(1,2,3,4)
y=(5,6,7,8)
#set

# %%
x="variable"
#str

# %%
#abstract two value
x=99
f=78
u=(x+f)
print(u)
# Out:
# 177

# %%
L2=["E",4,"Y",66,77,98]
print(L2)
# Out:
# ['E', 4, 'Y', 66, 77, 98]

# %%
print(type(L2))
# Out:
# <class 'list'>

# %%
print(len(L2))
# Out:
# 6

# %%
#L-2 29/55/66
x=77
y=88
print(x//y)
# Out:
# 0

# %%
print(x%y)
# Out:
# 77

# %%
colors=["red","yellow","blue","green"]
print("colors:",colors)
# Out:
# colors: ['red', 'yellow', 'blue', 'green']

# %%
coordinates=(33,87)
print("coordinates:",coordinates)
# Out:
# coordinates: (33, 87)

# %%
employee={"name":"ayushi","age":22,"contact":6755564334}
print("employee:",employee)
# Out:
# employee: {'name': 'ayushi', 'age': 22, 'contact': 6755564334}

# %%
flowers=["tulip","rose","lily","daisy"]
print("flower:",flowers)
# Out:
# flower: ['tulip', 'rose', 'lily', 'daisy']

# %%
person={"name":"ayushi","fav food":"italian","age":18}
print("person:",person)
# Out:
# person: {'name': 'ayushi', 'fav food': 'italian', 'age': 18}

# %%
value=(7,44,3)
print("value:",value)
# Out:
# value: (7, 44, 3)

# %%
x=30
print("x:",x)
x="I am int"
print("x:",x)
# Out:
# x: 30
# x: I am int

# %%
coordinates=[89,34,55,43,]
print(coordinates[2])
print(coordinates[0])
# Out:
# 55
# 89

# %%
flowers=["tulip","rose","lily","sunflower"]
flowers[3]="daisy"
print(flowers)
# Out:
# ['tulip', 'rose', 'lily', 'daisy']

# %% [markdown]
# # appending to a list

# %%
birds=["sparrow","parrot","eagle"]
birds.append("woodpeckor")
print(birds)
# Out:
# ['sparrow', 'parrot', 'eagle', 'woodpeckor']

# %% [markdown]
# # extend to a list

# %%
food1=["italian","chinese"]
food2=["indian","southindian"]
food1.extend(food2)
print(food1)
# Out:
# ['italian', 'chinese', 'indian', 'southindian']

# %%
no1=[1,3,4,5]
no2=[2,4,9,7]
no1.extend(no2)
print(no1)
# Out:
# [1, 3, 4, 5, 2, 4, 9, 7]

# %% [markdown]
# # remove elements

# %%
languages=["japanese","germen","spanish","mandarin"]
languages.remove("mandarin")
print(languages)
# Out:
# ['japanese', 'germen', 'spanish']

# %%
coordinates=[22,43,55,67]
coordinates.remove(55)
print(coordinates)
# Out:
# [22, 43, 67]

# %% [markdown]
# # modulus (x%y)

# %%
x=99
y=76
print(x%y)
# Out:
# 23

# %% [markdown]
# # floor division x//y

# %%
x=60
y=22
print(x//y)
# Out:
# 2

# %% [markdown]
# # simple division x/y

# %%
x=79
y=43
print(x/y)
# Out:
# 1.8372093023255813

# %%
x=71
x+=94
print(x)
# Out:
# 165

# %%
x=43
x-=62
print(x)
# Out:
# -19

# %%
x=10
x*=61
print(x)
# Out:
# 610

# %%
x=23
x/=7
print(x)
# Out:
# 3.2857142857142856

# %%
x=20
x//=7
print(x)
# Out:
# 2

# %% [markdown]
# # compairson opretor

# %%
x=7
y=8
print(x==y)
# Out:
# False

# %%
x=765
y=871
print(x>y)
# Out:
# False

# %% [markdown]
# # logical operator

# %%
x=67
print(x>90 and x<20)
# Out:
# False

# %%
x=89
print(x>9 or x<90)
# Out:
# True

# %%
x=34
print (not(x<9 and x>81))
# Out:
# True

# %% [markdown]
# # identity operator

# %%
x=["tulip","rose"]
y=["tulip","rose"]
x=y 
print(x is y)
# Out:
# True

# %%
x=["tulip","rose"]
y=["tulip","rose"]
x=y
print(x is not y)
# Out:
# False

# %%
x=10
y=12
print(x>=y)
# Out:
# False
