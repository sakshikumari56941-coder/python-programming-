# %%
t1=(1,2,3,4,5,6)
print(t1)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t1=(1,2,3,4,5,6)
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t1=(1,2,3,4,5,6)
print(len(t1))
# Out:
# 6

# %%
t2=("a","b","c","d","e")
print(t2)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
t2[3]
# Out:
# 'd'

# %%
t2[:5]
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
t2[-3:-1]
# Out:
# ('c', 'd')

# %%
t2[-4:]
# Out:
# ('b', 'c', 'd', 'e')
