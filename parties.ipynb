# %%
dress={"color":"olive green" , "brand":"ralph lauren" , "size": 38}
print(dress)
# Out:
# {'color': 'olive green', 'brand': 'ralph lauren', 'size': 38}

# %%
print(dress["brand"])
# Out:
# ralph lauren

# %%
print(dress["size"])
# Out:
# 38

# %%
sunglasses={"brand":"prada","color":"brown","prize": 900000}
print(sunglasses)
# Out:
# {'brand': 'prada', 'color': 'brown', 'prize': 900000}

# %%
print(sunglasses["brand"])
# Out:
# prada

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
print(cat["name"])
# Out:
# lisa

# %%
print(cat)
# Out:
# {'name': 'lisa', 'bread': 'persion', 'age': 1}

# %%
cat["color"]="white"
print(cat)
# Out:
# {'name': 'lisa', 'bread': 'persion', 'age': 1, 'color': 'white'}

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
cat["age"]=2 
print(cat)
# Out:
# {'name': 'lisa', 'bread': 'persion', 'age': 2}

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
del cat["age"] 
print(cat)
# Out:
# {'name': 'lisa', 'bread': 'persion'}

# %%
girl={"name":"ayushi","age":18}
copy_girl=girl.copy() 
print(copy_girl)
# Out:
# {'name': 'ayushi', 'age': 18}

# %%
girl={"name":"ayushi","age":18}
city= girl.get("city","unknown")
print(city)
# Out:
# unknown

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
print(cat["age"])
# Out:
# 1

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
print(len(cat))
# Out:
# 3

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
x=cat.get("bread") 
print(x)
# Out:
# persion

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
cat.keys()
# Out:
# dict_keys(['name', 'bread', 'age'])

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
cat["age"]=2
print(cat)
# Out:
# {'name': 'lisa', 'bread': 'persion', 'age': 2}

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
cat.update({"age":1})
print(cat)
# Out:
# {'name': 'lisa', 'bread': 'persion', 'age': 1}

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
cat.pop("age")
print(cat)
# Out:
# {'name': 'lisa', 'bread': 'persion'}

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
del cat["bread"]
print(cat)
# Out:
# {'name': 'lisa', 'age': 1}

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
cat.clear() 
print(cat)
# Out:
# {}

# %%
cat={"name": "lisa", "bread":"persion", "age":1}
sunglasses={"brand":"prada","color":"brown","prize": 900000}
cat=sunglasses.copy()
print(sunglasses)
# Out:
# {'brand': 'prada', 'color': 'brown', 'prize': 900000}

# %% [markdown]
# # nested dict

# %%
myfamily = {
    "child1":{
      "name": "emil",
      "year": 2004
    },
    "child2":{
      "name": "toby",
      "year": 2001
    },
    "child3":{
      "name": "lucy",
      "year": 2001
    }
  }

# %%
myfamily
# Out:
# {'child1': {'name': 'emil', 'year': 2004},
#  'child2': {'name': 'toby', 'year': 2001},
#  'child3': {'name': 'lucy', 'year': 2001}}

# %%
print(myfamily["child3"]["name"])
# Out:
# lucy

# %%
x=365
y=1999
v=x*y
print(v)
# Out:
# 729635

# %%
x=365
y=1999
v=x+y
print(v)
# Out:
# 2364

# %%
x=365
y=1999
v=x&y
print(v)
# Out:
# 333
