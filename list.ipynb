# %%
L1=[22,41,90,65,23]
print(L1)
print(type(L1))
print(len(L1))
# Out:
# [22, 41, 90, 65, 23]
# <class 'list'>
# 5

# %%
L2=["S",2,"T",6,9,True]
print(L2)
# Out:
# ['S', 2, 'T', 6, 9, True]

# %%
L3=[2.3,44.7,0.9]
print(L3)
# Out:
# [2.3, 44.7, 0.9]

# %%
list1=["A","D","O","P","O"]
print(list1)
# Out:
# ['A', 'D', 'O', 'P', 'O']

# %%
list1[0]
# Out:
# 'A'

# %%
list1[4]
# Out:
# 'O'

# %%
list1[3]
# Out:
# 'P'

# %%
list1[2:4]
# Out:
# ['O', 'P']

# %%
 list1[0:3]
# Out:
# ['A', 'D', 'O']

# %%
list1[0:5]
# Out:
# ['A', 'D', 'O', 'P', 'O']

# %%
list1[:5]
# Out:
# ['A', 'D', 'O', 'P', 'O']

# %%
list1[2:5]
# Out:
# ['O', 'P', 'O']

# %%
list1[:2]
# Out:
# ['A', 'D']

# %%
list1[3:5]
# Out:
# ['P', 'O']

# %%
list1[3:]
# Out:
# ['P', 'O']

# %%
list3=["A","B","C","D","E"]
list3[-3]
# Out:
# 'C'

# %%
list3[-4:-2]
# Out:
# ['B', 'C']

# %%
list3[-4:-1]
# Out:
# ['B', 'C', 'D']

# %% [markdown]
# # change items

# %%
l4=[1,22,3,4,55]
l4[3]=99
print(l4)
# Out:
# [1, 22, 3, 99, 55]

# %%
l4=[1,22,3,4,55]
l4[0:3]=80,33
print(l4)
# Out:
# [80, 33, 4, 55]

# %%
l4[2:4]
print(l4)
# Out:
# [80, 33, 4, 55]

# %%
l4[:5] 
print(l4)
# Out:
# [80, 33, 4, 55]

# %%
l5=["A","D","T","U","O"]
l5[0:4]
print(l5)
# Out:
# ['A', 'D', 'T', 'U', 'O']

# %%
l5[-4:-2]
print(l5)
# Out:
# ['A', 'D', 'T', 'U', 'O']

# %%
sports=["volleyball","football","hockey","baseball"]
sports[1]="cricket"
print(sports)
# Out:
# ['volleyball', 'cricket', 'hockey', 'baseball']

# %%
sports[0:2]="basketball","badminton"
print(sports)
# Out:
# ['basketball', 'badminton', 'hockey', 'baseball']

# %%
print(sports[-3])
# Out:
# badminton

# %%
print(len(sports))
# Out:
# 4

# %%
print(type(sports))
# Out:
# <class 'list'>

# %%
sports[1:3]
# Out:
# ['badminton', 'hockey']

# %% [markdown]
# # append

# %%
brands=["victoria secret","ralph lauren","bulgari","coach","hermes"]
brands.append("chanel")
print(brands)
# Out:
# ['victoria secret', 'ralph lauren', 'bulgari', 'coach', 'hermes', 'chanel']

# %%
brands.insert(3,"ysl")
print(brands)
# Out:
# ['victoria secret', 'ralph lauren', 'bulgari', 'ysl', 'coach', 'hermes', 'chanel']

# %%
company=["maybeline","loreal"]
brands.extend(company)
print(brands)
# Out:
# ['victoria secret', 'ralph lauren', 'bulgari', 'ysl', 'coach', 'hermes', 'chanel', 'maybeline', 'loreal']

# %% [markdown]
#  # pop list

# %%
l1=["ayushi","sakshi","keshav"]
l1.pop()
print(l1)
# Out:
# ['ayushi', 'sakshi']

# %% [markdown]
# # del list

# %%
l1=["ayushi","sakshi","keshav"]
del l1 [1]
print(l1)
# Out:
# ['ayushi', 'keshav']

# %% [markdown]
# # clear list

# %%
l1=["ayushi","sakshi","keshav"]
l1.clear()
print(l1)
# Out:
# []

# %% [markdown]
# # copy list

# %%
a=["apple","cherry"]
print(a)
# Out:
# ['apple', 'cherry']

# %%
b=a.copy() 
print(b)
